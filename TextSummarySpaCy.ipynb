# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
import warnings
warnings.filterwarnings('ignore')

# %%
with open('Article4Summary.txt', 'r', errors='ignore') as f:
    text = f.read()

stopwords = list(STOP_WORDS)
#print(stopwords)

#spacy.cli.download("en")
nlp = spacy.load('en_core_web_sm')

doc = nlp(text)

tokens = [token.text for token in doc]
#print(tokens)

# %%
#print(punctuation)
####################################
word_frequencies = {}
for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

#print(word_frequencies)
###################################
max_frequency = max(word_frequencies.values())
#print(max_frequency)
###########################
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frequency
    
#print(word_frequencies)

##################################################
sentence_tokens = [sent for sent in doc.sents]
#print(sentence_tokens)

# %%
word_frequencies
# Out:
# {'Internet': 0.125,
#  'usage': 0.125,
#  'India': 0.5625,
#  'statistics': 0.0625,
#  'facts': 0.0625,
#  '\n\n': 0.25,
#  'Published': 0.0625,
#  'Sandhya': 0.0625,
#  'Keelery': 0.0625,
#  'Aug': 0.0625,
#  '2': 0.0625,
#  '2021': 0.125,
#  '560': 0.0625,
#  'million': 0.375,
#  'internet': 1.0,
#  'users': 0.8125,
#  'second': 0.0625,
#  'largest': 0.125,
#  'online': 0.0625,
#  'market': 0.0625,
#  'world': 0.1875,
#  'ranked': 0.0625,
#  'China': 0.0625,
#  'estimated': 0.125,
#  '2023': 0.25,
#  '650': 0.0625,
#  'country': 0.5,
#  'Despite': 0.0625,
#  'large': 0.0625,
#  'base': 0.125,
#  'penetration': 0.1875,
#  'rate': 0.125,
#  'stood': 0.0625,
#  '50': 0.0625,
#  'percent': 0.25,
#  '2020': 0.125,
#  'meant': 0.0625,
#  'half': 0.0625,
#  '1.37': 0.0625,
#  'billion': 0.0625,
#  'Indians': 0.0625,
#  'access': 0.1875,
#  'year': 0.0625,
#  'consistent': 0.0625,
#  'increase': 0.0625,
#  'accessibility': 0.125,
#  'compared': 0.3125,
#  'years': 0.125,
#  'ago': 0.0625,
#  '27': 0.0625,
#  'digital': 0.1875,
#  'population': 0.1875,
#  '\n': 0.1875,
#  'use': 0.0625,
#  'largely': 0.0625,
#  'varied': 0.0625,
#  'based': 0.0625,
#  'factors': 0.0625,
#  'like': 0.0625,
#  'gender': 0.125,
#  'socio': 0.0625,
#  'economic': 0.0625,
#  'divide': 0.0625,
#  '300': 0.0625,
#  'rural': 0.25,
#  '335': 0.0625,
#  'urban': 0.1875,
#  'worth': 0.0625,
#  'mentioning': 0.0625,
#  'majority': 0.125,
#  'Indian': 0.125,
#  '20': 0.0625,
#  '29': 0.0625,
#  'age': 0.0625,
#  'slightly': 0.0625,
#  'higher': 0.0625,
#  'proportion': 0.0625,
#  'parts': 0.0625,
#  'time': 0.125,
#  'far': 0.0625,
#  'male': 0.0625,
#  'female': 0.0625,
#  'gap': 0.0625,
#  'increased': 0.125,
#  'hinterlands': 0.0625,
#  'metros': 0.0625,
#  'Indiaâ€': 0.0625,
#  '™': 0.0625,
#  's': 0.0625,
#  'accessed': 0.0625,
#  'mobile': 0.1875,
#  'phones': 0.0625,
#  'user': 0.125,
#  'expected': 0.125,
#  'grow': 0.0625,
#  '35': 0.0625,
#  'approximately': 0.0625,
#  '500': 0.0625,
#  'availability': 0.0625,
#  'cheap': 0.0625,
#  'data': 0.0625,
#  'plans': 0.0625,
#  'government': 0.0625,
#  'initiatives': 0.0625,
#  'Digital': 0.0625,
#  'campaign': 0.0625,
#  'worked': 0.0625,
#  'primary': 0.0625,
#  'Notably': 0.0625,
#  '4': 0.0625,
#  'G': 0.0625,
#  'networks': 0.125,
#  'widely': 0.0625,
#  '2019': 0.0625,
#  'aspect': 0.0625,
#  'shares': 0.0625,
#  'characteristics': 0.0625,
#  'global': 0.0625,
#  'passion': 0.0625,
#  'social': 0.25,
#  'media': 0.125,
#  'thrives': 0.0625,
#  'terms': 0.0625,
#  'spent': 0.0625,
#  'smartphones': 0.0625,
#  'Furthermore': 0.0625,
#  'share': 0.0625,
#  'jump': 0.0625,
#  '31': 0.0625,
#  'Facebook': 0.1875,
#  'popular': 0.0625,
#  'networking': 0.0625,
#  'site': 0.0625,
#  'fact': 0.0625,
#  '340': 0.0625}

# %%
from heapq import nlargest

select_length = int(len(sentence_tokens)*0.3)
#print(select_length)

summary = nlargest(select_length, sentence_scores, key=sentence_scores.get)
#print(summary)

final_summary = [word.text for word in summary]
summary = ''.join(final_summary)

print("******************************SUMMARY**************************************",summary)

print(len(text))
print(len(summary))
# Out:
# ******************************SUMMARY************************************** It was estimated that in 2020, there were over 300 million internet users in rural India compared to 335 million urban internet users.
# Internet users in India compared to the world
#
# One aspect where India shares the characteristics of other global internet users is its passion for social media.Internet usage in India - statistics & facts
#
# Published by Sandhya Keelery, Aug 2, 2021
#
# With over 560 million internet users, India is the second largest online market in the world, ranked only behind China.Despite the large base of internet users, the internet penetration rate in the country stood at around 50 percent in 2020.By 2023, the mobile internet user penetration was expected to grow to over 35 percent, or approximately 500 million users by 2023.
# 2396
# 755
